# %%
import pandas as pd
from matplotlib import pyplot as plt
# !pip install pycaret

tweet_data = pd.read_csv('/content/df_train_new.csv')
tweet_data.head()
# Out:
# ...
#        company     sentiment                                tweet
# 0  Borderlands  [1, 0, 0, 0]  ['getting', 'borderland', 'murder']
# 1  Borderlands  [1, 0, 0, 0]         ['coming', 'border', 'kill']
# 2  Borderlands  [1, 0, 0, 0]    ['getting', 'borderland', 'kill']
# 3  Borderlands  [1, 0, 0, 0]   ['coming', 'borderland', 'murder']
# 4  Borderlands  [1, 0, 0, 0]  ['getting', 'borderland', 'murder']

# %%
# sample 5% of data to be used as unseen data
data = tweet_data.sample(frac=0.95, random_state=786)

data_unseen = tweet_data.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)

print(data_unseen)
# print the revised shape
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
#           company     sentiment  \
# 0     Borderlands  [1, 0, 0, 0]
# 1     Borderlands  [0, 0, 1, 0]
# 2     Borderlands  [0, 1, 0, 0]
# 3     Borderlands  [0, 1, 0, 0]
# 4     Borderlands  [0, 0, 1, 0]
# ...           ...           ...
# 3609       Nvidia  [0, 0, 1, 0]
# 3610       Nvidia  [0, 0, 1, 0]
# 3611       Nvidia  [1, 0, 0, 0]
# 3612       Nvidia  [0, 1, 0, 0]
# 3613       Nvidia  [1, 0, 0, 0]
#
#                                                   tweet
# 0                   ['getting', 'borderland', 'murder']
# 1     ['rockhard', 'la', 'varlope', 'rare', 'powerfu...
# 2     ['like', 'everyone', 'else', 'border', 'countr...
# 3     ['practically', 'every', 'man', 'france', 'sli...
# 4     ['one', 'profzero', 'live', 'w', 'borderland',...
# ...                                                 ...
# 3609                                           ['next']
# 3610  ['since', 'nvidias', 'ready', 'announce', 'new...
# 3611                             ['love', 'everything']
# ...

# %%
# init setup
from pycaret.classification import *
s = setup(data = data, target = 'sentiment', session_id=123)
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_4b9b6_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4b9b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b9b6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4b9b6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b9b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b9b6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4b9b6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4b9b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b9b6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4b9b6_row1_col1" class="data row1 col1" >sentiment</td>
#     </tr>
#     <tr>
#       <th id="T_4b9b6_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
gbc= create_model('gbc')
lda= create_model('lda')
# Out:
# <style type="text/css">
# #T_0f07f_row10_col0, #T_0f07f_row10_col1, #T_0f07f_row10_col2, #T_0f07f_row10_col3, #T_0f07f_row10_col4, #T_0f07f_row10_col5, #T_0f07f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0f07f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f07f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0f07f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0f07f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0f07f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0f07f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0f07f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0f07f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
# !pip install --upgrade pycaret

# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available.")
else:
    device = torch.device("cpu")
    print("CUDA is not available.")

tunegbc=tune_model(gbc, verbose=False)
# Out:
# CUDA is available.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d86fae0353ab> in <cell line: 11>()
#       9     print("CUDA is not available.")
#      10
# ---> 11 tunegbc=tune_model(gbc, verbose=False)
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/functional.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1214     """
# ...

# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available.")
else:
    device = torch.device("cpu")
    print("CUDA is not available.")

tunelda=tune_model(lda)

# %%
tweet_data_int = pd.read_csv('/content/df_train_new_int.csv')
tweet_data_int.head()

# %%
# sample 5% of data to be used as unseen data
data_int = tweet_data_int.sample(frac=0.95, random_state=786)

data_int_unseen = tweet_data.drop(data.index)
data_int.reset_index(inplace=True, drop=True)
data_int_unseen.reset_index(inplace=True, drop=True)

print(data_int_unseen)
# print the revised shape
print('Data for Modeling: ' + str(data_int.shape))
print('Unseen Data For Predictions: ' + str(data_int_unseen.shape))

# %%
# init setup
from pycaret.classification import *
s = setup(data = data_int, target = 'sentiment', session_id=123)
best_model = compare_models()

# %%
ridge_int= create_model('ridge')
ada_int= create_model('ada')

# %%
tuneridge_intc=tune_model(ridge_int)
tuneada_int=tune_model(ada_int)
